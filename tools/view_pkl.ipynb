# %%
import pickle

pkl_file_name = '/home/JJ_Group/wangz/wangzhe21/CaDDN_wzh/output/kitti_models/CaDDN_DAIR-V2X_kitti_v/epoch_40_gpu_4_bs_8_lr_5E-4/eval/eval_with_train/epoch_36/val/result.pkl'
with open(pkl_file_name, 'rb') as f:
    infos = pickle.load(f)
    
print(len(infos))
print(infos[1].keys())
print(infos[1])


# print(infos[1]['annos'].keys())
# print(infos[1]['annos'])
# Out:
# 5965
# dict_keys(['name', 'truncated', 'occluded', 'alpha', 'bbox', 'dimensions', 'location', 'rotation_y', 'score', 'boxes_lidar', 'frame_id'])
# {'name': array(['Car', 'Car', 'Car', 'Car', 'Car', 'Car', 'Car', 'Car'],
#       dtype='<U10'), 'truncated': array([0., 0., 0., 0., 0., 0., 0., 0.]), 'occluded': array([0., 0., 0., 0., 0., 0., 0., 0.]), 'alpha': array([-2.7267087, -2.0927966, -6.5056973, -2.674575 , -2.9502172,
#        -2.9653726, -2.8785183, -2.8309267], dtype=float32), 'bbox': array([[ 630.94867,  577.5839 ,  763.109  ,  638.08356],
#        [   0.     ,  597.6991 ,  263.11554,  971.82153],
#        [1156.2296 ,  565.7199 , 1231.2582 ,  606.0919 ],
#        [ 580.2053 ,  581.09906,  698.3326 ,  632.70435],
#        [ 821.41235,  572.03564,  907.1501 ,  628.40594],
#        [ 898.3613 ,  568.45953,  946.25323,  600.74005],
#        [ 825.2378 ,  569.9658 ,  879.93   ,  602.59705],
# ...
